# %%
import sqlite3
import pandas as pd
pd.set_option('display.max_rows', None)     # Show every row
pd.set_option('display.max_columns', None)  # Show every column
pd.set_option('display.max_colwidth', None) # Show full cell content without cutting text
pd.set_option('display.width', None)        # Auto-detect terminal width to prevent wrapping

db_path="/workspaces/insults/memories/insults.db"
conn = sqlite3.connect(db_path)
pd.read_sql("SELECT * FROM agno_memories", conn)
# Out:
#                               memory_id                               memory  \
# 0  03f5441b-208e-4c66-a004-ff6a7a1be443  "The user is asking about agent B."
#
#                                          input agent_id team_id  user_id  \
# 0  do you have something to say about agent B?  agent-a    None  default
#
#         topics feedback  created_at  updated_at
# 0  ["agent B"]     None  1767308620  1767308620

# %%
conn.close()
